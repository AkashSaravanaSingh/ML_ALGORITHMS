# %% [markdown]
# <a href="https://colab.research.google.com/github/AkashSaravanaSingh/ML_ALGORITHMS/blob/main/RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c80b307e-5320-4715-b388-9c2320bf45ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c80b307e-5320-4715-b388-9c2320bf45ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('RNDFRST (2).csv')

# %%
x = df[['RollNo','Marks']]
y = df['Result']

# %%
df['Result'] = df['Result'].map({'Pass': 1, 'Fail': 0})

# %%
df.head()
# Out:
#    RollNo  Marks  Result
# 0       1     30       0
# 1       2     19       0
# 2       3     98       1
# 3       4     67       1
# 4       5     78       1

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(x_test)
print("Predictions:", y_pred.tolist())
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Predictions: ['Pass', 'Fail', 'Fail']
# Accuracy: 1.0

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='RollNo', y='Marks', hue='Result', data=df, palette='viridis')
plt.title('Random Forest Classifier Results')
plt.xlabel('RollNo')
# Out:
# Text(0.5, 0, 'RollNo')
